# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\amrit\\Downloads\\EDA\\EDA - Take Home (Week2) - Questions\\Life Expectancy Data.csv")

df.head()
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Polio  Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
df.describe( include ='all')

# 5 point summary of all columns including categorical columns as well. 

# Describe() function works with numerical data only by default.

# Population column has 652 non-standard missing values in variable. 

# Population column has numerical data and seems to have been wrongly classified as Categorical.
# Out:
#        Country         Year      Status  Life expectancy  Adult mortality  \
# count     2938  2938.000000        2922      2928.000000      2928.000000
# unique     193          NaN           2              NaN              NaN
# top       Mali          NaN  Developing              NaN              NaN
# freq        16          NaN        2413              NaN              NaN
# mean       NaN  2007.518720         NaN        69.224932       164.796448
# std        NaN     4.613841         NaN         9.523867       124.292079
# min        NaN  2000.000000         NaN        36.300000         1.000000
# 25%        NaN  2004.000000         NaN        63.100000        74.000000
# 50%        NaN  2008.000000         NaN        72.100000       144.000000
# 75%        NaN  2012.000000         NaN        75.700000       228.000000
# max        NaN  2015.000000         NaN        89.000000       723.000000
#
#         Infant deaths      Alcohol  Percentage expenditure  Hepatitis B  \
# ...

# %%
df.info()

# the dataset has 2938 rows and 22 columns of data.

# categorical columns in dataset are Country, Status, Population. 

# Population column has numerical data and seems to have been wrongly classified as Categorical (object).
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2922 non-null   object
#  3   Life expectancy                  2928 non-null   float64
#  4   Adult mortality                  2928 non-null   float64
#  5   Infant deaths                    2938 non-null   int64
#  6   Alcohol                          2744 non-null   float64
#  7   Percentage expenditure           2938 non-null   float64
#  8   Hepatitis B                      2385 non-null   float64
#  9   Measles                          2938 non-null   int64
#  10  BMI                              2904 non-null   float64
#  11  Under-five deaths                2938 non-null   int64
# ...

# %%
df.isnull().sum()

# count of null values present in columns.
# Out:
# Country                              0
# Year                                 0
# Status                              16
# Life expectancy                     10
# Adult mortality                     10
# Infant deaths                        0
# Alcohol                            194
# Percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
# BMI                                 34
# Under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
# HIV/AIDS                             0
# GDP                                448
# Population                           0
# Thinness  1-19 years                34
# Thinness 5-9 years                  34
# Income composition of resources    167
# Schooling                          163
# dtype: int64

# %%
#Q1. Check datatypes of each column and if any variable is wrongly identified, do needful ?

# Population column has numerical data and seems to have been wrongly classified as Categorical (object) datatype.

df['Population'] = pd.to_numeric(df['Population'] , errors ='coerce')

df['Population'].dtype
# Out:
# dtype('float64')

# %%
df['Population'].isnull().sum()

# The non-standard missing values in population column are now changed to 'NaN' and datatype is changed to float64.
# Out:
# 652

# %%
# Q2. create a dataframe containing count and percentage of missing entries in each variable.

Total = df.isnull().sum().sort_values( ascending = False )

Percent = ( df.isnull().sum() * 100 / df.isnull().count() ).sort_values(ascending = False)

missing_data = pd.concat([ Total, Percent ] , axis =1, keys = ['Total' , 'Percent'] )
missing_data

# Output shows that there are 22% of missing values in Population column. 15 columns in the dataset have missing values.
# Out:
#                                  Total    Percent
# Population                         652  22.191967
# Hepatitis B                        553  18.822328
# GDP                                448  15.248468
# Total expenditure                  226   7.692308
# Alcohol                            194   6.603131
# Income composition of resources    167   5.684139
# Schooling                          163   5.547992
# BMI                                 34   1.157250
# Thinness  1-19 years                34   1.157250
# Thinness 5-9 years                  34   1.157250
# Diphtheria                          19   0.646698
# Polio                               19   0.646698
# Status                              16   0.544588
# Adult mortality                     10   0.340368
# Life expectancy                     10   0.340368
# Under-five deaths                    0   0.000000
# HIV/AIDS                             0   0.000000
# Measles                              0   0.000000
# ...

# %%
# Q3a. Are there any extreme values present in government's total expenditure on health?

# Univariate analysis - Total expenditure column

sns.boxplot ( df['Total expenditure'] )
plt.xlabel('Total expenditure %')
plt.show()

# Percentages above 12.5% are outliers in the dataset.

# %%
# Q3b. Remove outliers present in 'Total expenditure' using quantiles of variable.

len(df['Total expenditure'])
# Out:
# 2938

# %%
# using quantiles method to remove the outliers.

Q1 = df['Total expenditure'].quantile(0.25)

Q3 = df['Total expenditure'].quantile(0.75)

IQR = Q3 - Q1
IQR
# Out:
# 3.2325

# %%
df = df[~((df['Total expenditure'] <(Q1 - 1.5 * IQR)) | (df['Total expenditure'] > (Q3 + 1.5 * IQR)) )]

len(df['Total expenditure'])

# count has reduced to 2906 from 2938 which implies removal of outliers.
# Out:
# 2906

# %%
#Q4. Split data such that X will contain all independent variables and y will contain target variable.

# 'Life expectancy' is target variable depending on remaining variables.

X = df.drop('Life expectancy' , axis = 1)
X.head()
# Out:
#        Country  Year      Status  Adult mortality  Infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    Percentage expenditure  Hepatitis B  Measles   BMI  ...  Polio  \
# 0               71.279624         65.0     1154  19.1  ...    6.0
# 1               73.523582         62.0      492  18.6  ...   58.0
# 2               73.219243         64.0      430  18.1  ...   62.0
# 3               78.184215         67.0     2787  17.6  ...   67.0
# 4                7.097109         68.0     3013  17.2  ...   68.0
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
# y variable contain only target variable.

y = df['Life expectancy']
y.head()
# Out:
# 0    65.0
# 1    59.9
# 2    59.9
# 3    59.5
# 4    59.2
# Name: Life expectancy, dtype: float64

# %%
#Q5. Split independent variables into 2 sets with proportion of 70:30.  

from sklearn.model_selection import train_test_split

X_train, X_test = train_test_split(X, test_size = 0.30, random_state = 10)

print('X_train', X_train.shape)
print('X_test', X_test.shape)
# Out:
# X_train (2034, 21)
# X_test (872, 21)

# %%
#Q6. How would you treat missing values in GDP column.

# GDP column has 448 missing values before treatment.

df['GDP'].isnull().sum()

#Missing values in GDP column after treatment are 424.
# Out:
# 424

# %%
424/ 2938 *100

# percent of missing values after treatment is 14.4 %

# considering GDP is an important column for life-expectancy data, we can replace missing values with mean if symmetry otherwise with median.
# Out:
# 14.431586113002043

# %%
df['GDP'].skew()

# S > 1
# Out:
# 3.200795965276571

# %%
sns.distplot(df['GDP'] )
plt.show()

# Thus, GDP column is highly skewed on right side. S >1 .

# %%
# replacing missing values with median.

df['GDP'] = df['GDP'].fillna(df['GDP'].median())

df['GDP'].isnull().any()
# Out:
# False

# %%
# Q7. There are 16 observations for which status of corresponding country is unknown, impute this status with an appropriate values.

print( df['Status'].isnull().sum() )

print( df['Status'].value_counts())

# Most rows in Status column have Developing as value. Hence, replacing missing values with 'Developing' in Status column.
# Out:
# 16
# Developing    2396
# Developed      494
# Name: Status, dtype: int64

# %%
df['Status'] = df['Status'].fillna(value = 'Developing')

df['Status'].isnull().any()
# Out:
# False

# %%
#Q8. Define a function to find extreme values in alcohol consumption.

sns.boxplot(df['Alcohol'])
plt.show()

# Boxplot shows presence of outliers in Alcohol column.

# %%
# function to find exact values.

#threshold = 3 is set as per z-score metric

outliers = []
def detect_outlier(data):
    threshold = 3
    mean = np.mean(data)
    std = np.std(data)
    
    for y in data:
        z_score = (y - mean)/std
        if np.abs(z_score) > threshold:
            outliers.append(y)
    return outliers

outlier_pt = detect_outlier(df.Alcohol)

print('Extreme values for alcohol:\n' + str(outlier_pt))

# The 3 values in output list are the extreme values in Alcohol consumption column.
# Out:
# Extreme values for alcohol:
# [17.31, 16.99, 17.87]

# %%
#Q9. Create a column 'Life_expectancy_level' such that it will contain 3 levels (High, Medium, Low) based on life expectancy.

df['Life expectancy'].describe()
# Out:
# count    2898.000000
# mean       69.205383
# std         9.519585
# min        36.300000
# 25%        63.025000
# 50%        72.100000
# 75%        75.600000
# max        89.000000
# Name: Life expectancy, dtype: float64

# %%
age = df['Life expectancy']

def feature(age):
    if age < df['Life expectancy'].quantile(0.25):
        return 'Low'
    if (age >= df['Life expectancy'].quantile(0.25))&((age<df['Life expectancy'].quantile(0.75))):
        return 'Medium'
    if (age > df['Life expectancy'].quantile(0.75)):
        return 'High'
    

df['Life_expectancy_level'] = df['Life expectancy'].apply(feature)

# %%
df.head()

# We created a new column as 'Life_expectancy_level' that categorises 'Life expectancy' into 3 levels Low, Medium, High.
# Out:
#        Country  Year      Status  Life expectancy  Adult mortality  \
# 0  Afghanistan  2015  Developing             65.0            263.0
# 1  Afghanistan  2014  Developing             59.9            271.0
# 2  Afghanistan  2013  Developing             59.9            268.0
# 3  Afghanistan  2012  Developing             59.5            272.0
# 4  Afghanistan  2011  Developing             59.2            275.0
#
#    Infant deaths  Alcohol  Percentage expenditure  Hepatitis B  Measles  ...  \
# 0             62     0.01               71.279624         65.0     1154  ...
# 1             64     0.01               73.523582         62.0      492  ...
# 2             66     0.01               73.219243         64.0      430  ...
# 3             69     0.01               78.184215         67.0     2787  ...
# 4             71     0.01                7.097109         68.0     3013  ...
#
#    Total expenditure  Diphtheria  HIV/AIDS         GDP  Population  \
# ...

# %%
#Q10. Check how life expectancy has changed over years in China.

plt.figure(figsize = (15,8))

sns.boxplot( x = df['Country'][df['Country'] == 'China'] , y = df['Year'] , hue = df['Life_expectancy_level'])

plt.show()

# Boxplot shows that life expectancy has significantly improved in China over the years.
